# %% [markdown]
# you can access the sql query code, the data retrieved, the python codes used and the ipython notebooks mentioned here with on the [github reposity here](https://github.com/rahulporuri/astro_data_projects/tree/master/quasar_coordinates). for a brief theory on how the conversion works, refer [here](http://physics.stackexchange.com/questions/88663/converting-between-galactic-and-ecliptic-coordinates)

# %%
# !ls
# Out:
# gal_coordinates_plot.py  MyTable_rahul.poruri.csv  quasars_coordinates_galactic.png  quasars_coordinates_ra,dec.png  sdss_coverage.jpg	sql_query  Untitled0.ipynb

# %% [markdown]
# sql query request
# ===

# %% [markdown]
# ```
# select
# plateX.plate, plateX.mjd,
# PhotoPrimary.ra, PhotoPrimary.dec, PhotoPrimary.l, PhotoPrimary.b, PhotoPrimary.ObjID,
# specObj.fiberID, specObj.z into mydb.MyTable from PhotoPrimary, specObj, plateX
#
# where
# specObj.bestObjid = PhotoPrimary.ObjID
# AND plateX.plateID = specObj.plateID
# AND specObj.class = 'qso'
# AND specObj.zWarning = 0
# AND PhotoPrimary.modelMag_u < 22.3
# AND PhotoPrimary.modelMag_g < 22.6
# AND PhotoPrimary.modelMag_r < 22.7
# AND PhotoPrimary.modelMag_i < 22.4
# AND PhotoPrimary.modelMag_z < 20.5
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = [line.split(',') for line in open('MyTable_rahul.poruri.csv')]

# %%
print data[0]
print data[1]
# Out:
# ['plate', 'mjd', 'ra', 'dec', 'l', 'b', 'ObjID', 'fiberID', 'z\n']
# ['339', '51692', '196.240031499488', '-1.23006495320075', '310.018771055342', '61.4554170817091', '1237648702972100785', '413', '0.4322039\n']

# %%
#ra = np.zeros(len(data))
#dec = np.zeros(len(data))
ra, dec = [], []
for i in range(1,len(data)):
    temp = float(data[i][2])
    temp1 = float(data[i][3])
    ra.append(temp)
    dec.append(temp1)
    #ra[i] = float(temp)
    #dec[i] = float(temp1)

# %%
ra = np.asarray(ra)
dec = np.asarray(dec)
ra = (ra-180)*(np.pi/180)
dec = dec*(np.pi/180)

# %% [raw]
# ra is from -np.pi to np.pi and dec is from -np.pi/2 to np.pi/2

# %%
data[i][3]
# Out:
# '4.58109050425403'

# %%
plt.subplot(111,projection='aitoff')
plt.grid(True)
plt.scatter(ra,dec,s=5)
plt.title('Quasars from the SDSS DR10')
plt.xlabel('ra')
plt.ylabel('dec')

# %%
#ra = np.zeros(len(data))
#dec = np.zeros(len(data))
l, b = [], []
for i in range(1,len(data)):
    temp = float(data[i][4])
    temp1 = float(data[i][5])
    l.append(temp)
    b.append(temp1)
    #ra[i] = float(temp)
    #dec[i] = float(temp1)

# %%
b = np.asarray(b)
l = np.asarray(l)
l = (l-180)*(np.pi/180)
b = b*(np.pi/180)

# %%
plt.subplot(111,projection='aitoff')
plt.grid(True)
plt.scatter(l,b,s=5)
plt.title('Quasars from the SDSS DR10')
plt.xlabel('galactic longitude')
plt.ylabel('galactic latitude')

# %%
np.arcsin(np.sin(dec[i-1])*np.cos(62.6*np.pi/180) - np.cos(dec[i-1])*np.sin((ra[i-1]*180/np.pi-282.25)*np.pi/180)*np.sin(62.6*np.pi/180))
# Out:
# -0.75255607438023486

# %%
33*np.pi/180 + np.arccos(np.cos(dec[i-1])*np.cos(ra[i-1]*180/np.pi-282.25)*np.pi/180)
# Out:
# 2.1590106755641378

# %%
l,b = [], []
for j in range(len(ra)):
    temp = np.arcsin(np.sin(dec[j])*np.cos(62.6*np.pi/180) - np.cos(dec[j])*np.sin((ra[j]*180/np.pi-102.25)*np.pi/180)*np.sin(62.6*np.pi/180))
    b.append(temp)
    l.append(33*np.pi/180 + (np.arccos(np.cos(dec[j])*np.cos(ra[j]*180/np.pi-102.25)*np.pi/180))/np.cos(temp))

# %%
np.cos(np.pi)
# Out:
# -1.0

# %%
ra, dec
# Out:
# (array([ 0.28344202,  0.32248421,  0.3672801 , ..., -0.41337493,
#          0.77297198, -0.406202  ]),
#  array([-0.02146868, -0.01996694, -0.0211558 , ...,  0.07858323,
#          1.05515334,  0.07995511]))

# %%
np.asarray(l), np.asarray(b)
# Out:
# (array([ 1.06663568,  1.06175717,  1.05004984, ...,  0.85224613,
#          0.88113941,  0.85873871]),
#  array([ 2.15328933,  2.15543783,  2.13123681, ...,  2.12998947,
#          2.14540514,  2.12952692]))

# %%
from astropy import coordinates as coord
from astropy import units as u

# %%
ra[j], dec[j]
# Out:
# (-0.40620200358382297, 0.079955112631080127)

# %% [markdown]
# now we can use the coordinate transformation utilities available in the astropy library. you can refer to the docs [here](http://astropy.readthedocs.org/en/latest/coordinates/) or [here](http://docs.astropy.org/en/v0.2.1/coordinates/)

# %%
c = coord.ICRSCoordinates(ra = ra[j]*180/np.pi, dec= dec[j]*180/np.pi, unit = (u.degree, u.degree))

# %%
print c.galactic.l*180/np.pi, c.galactic.b*180/np.pi, c.galactic
# Out:
# 69.6361rad -42.85rad <Galactic l=69.63606 deg, b=-42.85000 deg>

# %%
b,l = [], []
for j in range(100):
    c = coord.ICRSCoordinates(ra = ra[j]*180/np.pi, dec= dec[j]*180/np.pi, unit = (u.degree, u.degree))
    b.append(c.galactic.b.to_string(decimal=True))
    l.append(c.galactic.l.to_string(decimal=True))

# %%
temp = []
for i in range(10):
    c = coord.ICRSCoordinates(ra = ra[j]*180/np.pi, dec= dec[j]*180/np.pi, unit = (u.degree, u.degree))
    #print c.galactic.b.format(u.radian, decimal=True)
    tempp = c.galactic.b.format(u.radian, decimal=True)
    temp.append(tempp)
#print c.galactic.b
#print b,l
#np.asarray(b)

# %%
print temp
# Out:
# [u'-0.88684', u'-0.88684', u'-0.88684', u'-0.88684', u'-0.88684', u'-0.88684', u'-0.88684', u'-0.88684', u'-0.88684', u'-0.88684']

# %%
plt.subplot(111,projection='aitoff')
plt.scatter(b,l,s=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-dfc9bf85c990> in <module>()
#       1 plt.subplot(111,projection='aitoff')
# ----> 2 plt.scatter(b,l,s=5)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, hold, **kwargs)
#    3192         ret = ax.scatter(x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3193                          vmin=vmin, vmax=vmax, alpha=alpha,
# -> 3194                          linewidths=linewidths, verts=verts, **kwargs)
#    3195         draw_if_interactive()
#    3196     finally:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, **kwargs)
#    3566             self.cla()
#    3567
# ...

# %% [markdown]
# gnuplot code
# ===
# ```
# gnuplot> set term wxt
# gnuplot> set datafile separator ','
# gnuplot> plot 'MyTable_rahul.poruri.csv' u 3:4 or 5:6 for a simple pllot of (ra, dec) or (l, b).
# need to figure out how to do projections in gnuplot
# ```
